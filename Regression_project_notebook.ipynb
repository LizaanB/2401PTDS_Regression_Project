# %% [markdown]
# # 2401PTDS_Regression_Project
# ## Average temperature from the agri-food sector
#
# ![image.png](attachment:4b3fdddb-1fa9-418f-80a6-f758e6255bbf.png)

# %% [markdown]
# # Project Overview

# %% [markdown]
# # Importing Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import csv

# Display outline inline
# %matplotlib inline

# Libaries for Handing Error
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading Data Set

# %%
df = pd.read_csv('co2_emissions_from_agri.csv')
